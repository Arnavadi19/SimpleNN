# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from itertools import product

# Directories
train_dir = '/home/arnav/Documents/research_project/assignment01/images/train'
test_dir = '/home/arnav/Documents/research_project/assignment01/images/test'
val_dir = '/home/arnav/Documents/research_project/assignment01/images/val'

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

learning_rates = [0.001, 0.0001]
batch_sizes = [32, 64]
activation_functions = {
    'ReLU': nn.ReLU(inplace=True)
    # 'GeLU': nn.GELU(),
    # 'SeLU': nn.SELU(inplace=True),
    # 'SiLU': nn.SiLU(inplace=True),
    # 'Sigmoid': nn.Sigmoid()
}
num_epochs_list = [25]

# Transformations
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop(227),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

valid_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to get data loaders
def get_data_loaders(train_dir, val_dir, test_dir, batch_size):
    train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
    valid_dataset = datasets.ImageFolder(root=val_dir, transform=valid_transform)
    test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    return train_loader, valid_loader, test_loader

# Model definition
class AlexNet(nn.Module):
    def __init__(self, num_classes, activation):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            activation,
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            activation,
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            activation,
            nn.Dropout(),
            nn.Linear(4096, 4096),
            activation,
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Function to train and evaluate the model
def train_and_evaluate(model, train_loader, valid_loader, test_loader, num_epochs, learning_rate):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate, weight_decay=0.005, momentum=0.9)
    
    train_losses = []
    valid_losses = []
    valid_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for i, (images, labels) in enumerate(train_loader):
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
        
        train_losses.append(running_loss / len(train_loader))
        
        model.eval()
        running_val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in valid_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        valid_loss = running_val_loss / len(valid_loader)
        valid_losses.append(valid_loss)
        accuracy = correct / total
        valid_accuracies.append(accuracy)
        print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {valid_loss:.4f}, Val Accuracy: {100 * accuracy:.2f} %')
            
    avg_val_accuracy = sum(valid_accuracies) / len(valid_accuracies)
    print(f'Average Validation Accuracy: {100 * avg_val_accuracy:.2f} %')
    
    # Test accuracy
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        test_accuracy = correct / total
        print(f'Test Accuracy: {100 * test_accuracy:.2f} %')
        return test_accuracy

# Running the experiments
results = []
test_accuracies = []

for lr, bs, (name, activation), epochs in product(learning_rates, batch_sizes, activation_functions.items(), num_epochs_list):
    print(f"Running with lr={lr}, batch_size={bs}, activation={name}, epochs={epochs}")
    train_loader, valid_loader, test_loader = get_data_loaders(train_dir, val_dir, test_dir, bs)
    model = AlexNet(num_classes=2, activation=activation).to(device)
    test_accuracy = train_and_evaluate(model, train_loader, valid_loader, test_loader, epochs, lr)
    results.append((lr, bs, name, epochs, test_accuracy))
    test_accuracies.append(test_accuracy)

plt.figure(figsize=(12, 6))
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Experiment')
plt.ylabel('Accuracy')
plt.title('Test Accuracies for Different Hyperparameters')
plt.legend()
plt.show()
# Out:
# Running with lr=0.001, batch_size=32, activation=ReLU, epochs=25
# Epoch [1/25], Train Loss: 0.6920, Val Loss: 0.6997, Val Accuracy: 16.98 %
# Epoch [2/25], Train Loss: 0.6878, Val Loss: 0.7136, Val Accuracy: 16.98 %
# Epoch [3/25], Train Loss: 0.6831, Val Loss: 0.7241, Val Accuracy: 16.98 %
# Epoch [4/25], Train Loss: 0.6793, Val Loss: 0.7342, Val Accuracy: 16.98 %
# Epoch [5/25], Train Loss: 0.6754, Val Loss: 0.7454, Val Accuracy: 16.98 %
# Epoch [6/25], Train Loss: 0.6711, Val Loss: 0.7592, Val Accuracy: 16.98 %
# Epoch [7/25], Train Loss: 0.6663, Val Loss: 0.7717, Val Accuracy: 16.98 %
# Epoch [8/25], Train Loss: 0.6622, Val Loss: 0.7972, Val Accuracy: 16.98 %
# Epoch [9/25], Train Loss: 0.6536, Val Loss: 0.7878, Val Accuracy: 16.98 %
# Epoch [10/25], Train Loss: 0.6500, Val Loss: 0.7903, Val Accuracy: 16.98 %
# Epoch [11/25], Train Loss: 0.6407, Val Loss: 0.7844, Val Accuracy: 16.98 %
# Epoch [12/25], Train Loss: 0.6305, Val Loss: 0.7770, Val Accuracy: 16.98 %
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from itertools import product

# Directories
train_dir = '/home/arnav/Documents/research_project/assignment01/images/train'
test_dir = '/home/arnav/Documents/research_project/assignment01/images/test'
val_dir = '/home/arnav/Documents/research_project/assignment01/images/val'

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

learning_rates = [0.001]
batch_sizes = [32]
activation_functions = {
    'ReLU': nn.ReLU(inplace=True),
    'GeLU': nn.GELU(),
    'SeLU': nn.SELU(inplace=True),
    'SiLU': nn.SiLU(inplace=True),
    'Sigmoid': nn.Sigmoid()
}
num_epochs_list = [25]

# Transformations
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop(227),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

valid_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to get data loaders
def get_data_loaders(train_dir, val_dir, test_dir, batch_size):
    train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
    valid_dataset = datasets.ImageFolder(root=val_dir, transform=valid_transform)
    test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    return train_loader, valid_loader, test_loader

# Model definition
class AlexNet(nn.Module):
    def __init__(self, num_classes, activation):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            activation,
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            activation,
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            activation,
            nn.Dropout(),
            nn.Linear(4096, 4096),
            activation,
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Function to train and evaluate the model
def train_and_evaluate(model, train_loader, valid_loader, test_loader, num_epochs, learning_rate):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate, weight_decay=0.005, momentum=0.9)
    
    train_losses = []
    valid_losses = []
    valid_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for i, (images, labels) in enumerate(train_loader):
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
        
        train_losses.append(running_loss / len(train_loader))
        
        model.eval()
        running_val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in valid_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        valid_loss = running_val_loss / len(valid_loader)
        valid_losses.append(valid_loss)
        accuracy = correct / total
        valid_accuracies.append(accuracy)
        print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {valid_loss:.4f}, Val Accuracy: {100 * accuracy:.2f} %')
            
    avg_val_accuracy = sum(valid_accuracies) / len(valid_accuracies)
    print(f'Average Validation Accuracy: {100 * avg_val_accuracy:.2f} %')
    
    # Test accuracy
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        test_accuracy = correct / total
        print(f'Test Accuracy: {100 * test_accuracy:.2f} %')
        return test_accuracy

# Running the experiments
results = []
test_accuracies = []

for lr, bs, (name, activation), epochs in product(learning_rates, batch_sizes, activation_functions.items(), num_epochs_list):
    print(f"Running with lr={lr}, batch_size={bs}, activation={name}, epochs={epochs}")
    train_loader, valid_loader, test_loader = get_data_loaders(train_dir, val_dir, test_dir, bs)
    model = AlexNet(num_classes=2, activation=activation).to(device)
    test_accuracy = train_and_evaluate(model, train_loader, valid_loader, test_loader, epochs, lr)
    results.append((lr, bs, name, epochs, test_accuracy))
    test_accuracies.append(test_accuracy)

plt.figure(figsize=(12, 6))
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Experiment')
plt.ylabel('Accuracy')
plt.title('Test Accuracies for Different Hyperparameters')
plt.legend()
plt.show()
# Out:
# Running with lr=0.001, batch_size=32, activation=ReLU, epochs=25
# Epoch [1/25], Train Loss: 0.6900, Val Loss: 0.7050, Val Accuracy: 16.98 %
# Epoch [2/25], Train Loss: 0.6864, Val Loss: 0.7150, Val Accuracy: 16.98 %
# Epoch [3/25], Train Loss: 0.6834, Val Loss: 0.7260, Val Accuracy: 16.98 %
# Epoch [4/25], Train Loss: 0.6801, Val Loss: 0.7340, Val Accuracy: 16.98 %
# Epoch [5/25], Train Loss: 0.6791, Val Loss: 0.7446, Val Accuracy: 16.98 %
# Epoch [6/25], Train Loss: 0.6771, Val Loss: 0.7514, Val Accuracy: 16.98 %
# Epoch [7/25], Train Loss: 0.6747, Val Loss: 0.7587, Val Accuracy: 16.98 %
# Epoch [8/25], Train Loss: 0.6717, Val Loss: 0.7651, Val Accuracy: 16.98 %
# Epoch [9/25], Train Loss: 0.6715, Val Loss: 0.7749, Val Accuracy: 16.98 %
# Epoch [10/25], Train Loss: 0.6646, Val Loss: 0.7774, Val Accuracy: 16.98 %
# Epoch [11/25], Train Loss: 0.6575, Val Loss: 0.7903, Val Accuracy: 16.98 %
# Epoch [12/25], Train Loss: 0.6547, Val Loss: 0.8022, Val Accuracy: 16.98 %
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from itertools import product

# Directories
train_dir = '/home/arnav/Documents/research_project/assignment01/images/train'
test_dir = '/home/arnav/Documents/research_project/assignment01/images/test'
val_dir = '/home/arnav/Documents/research_project/assignment01/images/val'

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

learning_rates = [0.001]
batch_sizes = [32]
activation_functions = {
    'ReLU': nn.ReLU(inplace=True),
    'SeLU': nn.SELU(inplace=True)
}
num_epochs_list = [50, 100]

# Transformations
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop(227),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

valid_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to get data loaders
def get_data_loaders(train_dir, val_dir, test_dir, batch_size):
    train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
    valid_dataset = datasets.ImageFolder(root=val_dir, transform=valid_transform)
    test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    return train_loader, valid_loader, test_loader

# Model definition
class AlexNet(nn.Module):
    def __init__(self, num_classes, activation):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            activation,
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            activation,
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            activation,
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            activation,
            nn.Dropout(),
            nn.Linear(4096, 4096),
            activation,
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Function to train and evaluate the model
def train_and_evaluate(model, train_loader, valid_loader, test_loader, num_epochs, learning_rate):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate, weight_decay=0.005, momentum=0.9)
    
    train_losses = []
    valid_losses = []
    valid_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for i, (images, labels) in enumerate(train_loader):
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
        
        train_losses.append(running_loss / len(train_loader))
        
        model.eval()
        running_val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in valid_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        valid_loss = running_val_loss / len(valid_loader)
        valid_losses.append(valid_loss)
        accuracy = correct / total
        valid_accuracies.append(accuracy)
        print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {valid_loss:.4f}, Val Accuracy: {100 * accuracy:.2f} %')
            
    avg_val_accuracy = sum(valid_accuracies) / len(valid_accuracies)
    print(f'Average Validation Accuracy: {100 * avg_val_accuracy:.2f} %')
    
    # Test accuracy
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        test_accuracy = correct / total
        print(f'Test Accuracy: {100 * test_accuracy:.2f} %')
        return test_accuracy

# Running the experiments
results = []
test_accuracies = []

for lr, bs, (name, activation), epochs in product(learning_rates, batch_sizes, activation_functions.items(), num_epochs_list):
    print(f"Running with lr={lr}, batch_size={bs}, activation={name}, epochs={epochs}")
    train_loader, valid_loader, test_loader = get_data_loaders(train_dir, val_dir, test_dir, bs)
    model = AlexNet(num_classes=2, activation=activation).to(device)
    test_accuracy = train_and_evaluate(model, train_loader, valid_loader, test_loader, epochs, lr)
    results.append((lr, bs, name, epochs, test_accuracy))
    test_accuracies.append(test_accuracy)

plt.figure(figsize=(12, 6))
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Experiment')
plt.ylabel('Accuracy')
plt.title('Test Accuracies for Different Hyperparameters')
plt.legend()
plt.show()
# Out:
# Running with lr=0.001, batch_size=32, activation=ReLU, epochs=50
# Epoch [1/50], Train Loss: 0.6892, Val Loss: 0.7063, Val Accuracy: 16.98 %
# Epoch [2/50], Train Loss: 0.6845, Val Loss: 0.7175, Val Accuracy: 16.98 %
# Epoch [3/50], Train Loss: 0.6804, Val Loss: 0.7296, Val Accuracy: 16.98 %
# Epoch [4/50], Train Loss: 0.6761, Val Loss: 0.7411, Val Accuracy: 16.98 %
# Epoch [5/50], Train Loss: 0.6735, Val Loss: 0.7552, Val Accuracy: 16.98 %
# Epoch [6/50], Train Loss: 0.6669, Val Loss: 0.7659, Val Accuracy: 16.98 %
# Epoch [7/50], Train Loss: 0.6622, Val Loss: 0.7873, Val Accuracy: 16.98 %
# Epoch [8/50], Train Loss: 0.6530, Val Loss: 0.7970, Val Accuracy: 16.98 %
# Epoch [9/50], Train Loss: 0.6472, Val Loss: 0.7978, Val Accuracy: 16.98 %
# Epoch [10/50], Train Loss: 0.6412, Val Loss: 0.7833, Val Accuracy: 16.98 %
# Epoch [11/50], Train Loss: 0.6300, Val Loss: 0.7927, Val Accuracy: 16.98 %
# Epoch [12/50], Train Loss: 0.6240, Val Loss: 0.7573, Val Accuracy: 16.98 %
# ...
