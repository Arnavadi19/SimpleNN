# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
train_dir = '/home/arnav/Documents/research_project/assignment01/images/train'
test_dir = '/home/arnav/Documents/research_project/assignment01/images/test'
val_dir = '/home/arnav/Documents/research_project/assignment01/images/val'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),  
    transforms.RandomCrop(227),     
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

valid_transform = transforms.Compose([
    transforms.Resize((227, 227)),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Function to get train and valid loaders
def get_train_valid_loader(train_dir, val_dir, batch_size, augment, random_seed, valid_size=0.1, shuffle=True):
    normalize = transforms.Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.2010])

    valid_transform = transforms.Compose([
        transforms.Resize((227, 227)),
        transforms.ToTensor(),
        normalize,
    ])

    if augment:
        train_transform = transforms.Compose([
            transforms.Resize((256, 256)),  
            transforms.RandomCrop(227),    
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])
    else:
        train_transform = transforms.Compose([
            transforms.Resize((227, 227)),
            transforms.ToTensor(),
            normalize,
        ])

    train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
    valid_dataset = datasets.ImageFolder(root=val_dir, transform=valid_transform)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, valid_loader

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
num_classes = 10
num_epochs = 25
batch_size = 32
learning_rate = 0.0001

train_loader, valid_loader = get_train_valid_loader(train_dir, val_dir, batch_size, augment=True, random_seed=42)

model = AlexNet(num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

total_step = len(train_loader)

# %%
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
          .format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))
    
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in valid_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            del images, labels, outputs
    
        print('Accuracy of the network on the {} validation images: {} '.format(len(valid_loader.dataset), correct / total))

test_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Epoch [1/25], Step [21/21], Loss: 0.5522
# Accuracy of the network on the 106 validation images: 0.16981132075471697
# Epoch [2/25], Step [21/21], Loss: 0.5941
# Accuracy of the network on the 106 validation images: 0.39622641509433965
# Epoch [3/25], Step [21/21], Loss: 0.5736
# Accuracy of the network on the 106 validation images: 0.8207547169811321
# Epoch [4/25], Step [21/21], Loss: 0.6861
# Accuracy of the network on the 106 validation images: 0.5754716981132075
# Epoch [5/25], Step [21/21], Loss: 0.5455
# Accuracy of the network on the 106 validation images: 0.6320754716981132
# Epoch [6/25], Step [21/21], Loss: 0.4469
# Accuracy of the network on the 106 validation images: 0.5283018867924528
# Epoch [7/25], Step [21/21], Loss: 0.3103
# Accuracy of the network on the 106 validation images: 0.6698113207547169
# Epoch [8/25], Step [21/21], Loss: 0.3235
# Accuracy of the network on the 106 validation images: 0.6981132075471698
# Epoch [9/25], Step [21/21], Loss: 0.2749
# Accuracy of the network on the 106 validation images: 0.8490566037735849
# Epoch [10/25], Step [21/21], Loss: 0.3108
# Accuracy of the network on the 106 validation images: 0.6132075471698113
# Epoch [11/25], Step [21/21], Loss: 0.3046
# Accuracy of the network on the 106 validation images: 0.7547169811320755
# Epoch [12/25], Step [21/21], Loss: 0.2775
# Accuracy of the network on the 106 validation images: 0.7452830188679245
# Epoch [13/25], Step [21/21], Loss: 0.4324
# Accuracy of the network on the 106 validation images: 0.8962264150943396
# Epoch [14/25], Step [21/21], Loss: 0.3311
# Accuracy of the network on the 106 validation images: 0.7830188679245284
# Epoch [15/25], Step [21/21], Loss: 0.4178
# Accuracy of the network on the 106 validation images: 0.8018867924528302
# Epoch [16/25], Step [21/21], Loss: 0.2106
# Accuracy of the network on the 106 validation images: 0.6226415094339622
# Epoch [17/25], Step [21/21], Loss: 0.2585
# Accuracy of the network on the 106 validation images: 0.7924528301886793
# Epoch [18/25], Step [21/21], Loss: 0.1101
# Accuracy of the network on the 106 validation images: 0.7735849056603774
# Epoch [19/25], Step [21/21], Loss: 0.4640
# Accuracy of the network on the 106 validation images: 0.7547169811320755
# Epoch [20/25], Step [21/21], Loss: 0.1695
# Accuracy of the network on the 106 validation images: 0.6226415094339622
# Epoch [21/25], Step [21/21], Loss: 0.0947
# Accuracy of the network on the 106 validation images: 0.8301886792452831
# Epoch [22/25], Step [21/21], Loss: 0.5831
# Accuracy of the network on the 106 validation images: 0.8584905660377359
# Epoch [23/25], Step [21/21], Loss: 0.3141
# Accuracy of the network on the 106 validation images: 0.8301886792452831
# Epoch [24/25], Step [21/21], Loss: 0.0855
# Accuracy of the network on the 106 validation images: 0.8584905660377359
# Epoch [25/25], Step [21/21], Loss: 0.0579
# Accuracy of the network on the 106 validation images: 0.8679245283018868

# %%
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs
        
    accuracy = correct/total
    accuracies = []
    accuracies.append(accuracy)
    print('Accuracy of the network on the {} test images: {} '.format(len(test_loader.dataset), accuracy))
# Out:
# Accuracy of the network on the 163 test images: 0.4662576687116564

# %%
num_classes = 10
num_epochs = 25
batch_size = 64
learning_rate = 0.0001

train_loader, valid_loader = get_train_valid_loader(train_dir, val_dir, batch_size, augment=True, random_seed=42)

model = AlexNet(num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

total_step = len(train_loader)


for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
          .format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))
    
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in valid_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            del images, labels, outputs
    
        print('Accuracy of the network on the {} validation images: {} '.format(len(valid_loader.dataset), correct / total))

test_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs
        
    accuracy = correct/total
    accuracies = []
    accuracies.append(accuracy)
    print('Accuracy of the network on the {} test images: {} '.format(len(test_loader.dataset), accuracy))
# Out:
# Epoch [1/25], Step [11/11], Loss: 0.6832
# Accuracy of the network on the 106 validation images: 0.8301886792452831
# Epoch [2/25], Step [11/11], Loss: 0.6424
# Accuracy of the network on the 106 validation images: 0.16981132075471697
# Epoch [3/25], Step [11/11], Loss: 0.5997
# Accuracy of the network on the 106 validation images: 0.3018867924528302
# Epoch [4/25], Step [11/11], Loss: 0.5663
# Accuracy of the network on the 106 validation images: 0.7075471698113207
# Epoch [5/25], Step [11/11], Loss: 0.5374
# Accuracy of the network on the 106 validation images: 0.8490566037735849
# Epoch [6/25], Step [11/11], Loss: 0.4778
# Accuracy of the network on the 106 validation images: 0.4528301886792453
# Epoch [7/25], Step [11/11], Loss: 0.4646
# Accuracy of the network on the 106 validation images: 0.7924528301886793
# Epoch [8/25], Step [11/11], Loss: 0.4507
# Accuracy of the network on the 106 validation images: 0.6886792452830188
# Epoch [9/25], Step [11/11], Loss: 0.3649
# Accuracy of the network on the 106 validation images: 0.8301886792452831
# Epoch [10/25], Step [11/11], Loss: 0.5704
# Accuracy of the network on the 106 validation images: 0.8584905660377359
# Epoch [11/25], Step [11/11], Loss: 0.6025
# Accuracy of the network on the 106 validation images: 0.8490566037735849
# Epoch [12/25], Step [11/11], Loss: 0.3053
# Accuracy of the network on the 106 validation images: 0.7547169811320755
# Epoch [13/25], Step [11/11], Loss: 0.3277
# Accuracy of the network on the 106 validation images: 0.6132075471698113
# Epoch [14/25], Step [11/11], Loss: 0.3131
# Accuracy of the network on the 106 validation images: 0.8113207547169812
# Epoch [15/25], Step [11/11], Loss: 0.3290
# Accuracy of the network on the 106 validation images: 0.5188679245283019
# Epoch [16/25], Step [11/11], Loss: 0.3788
# Accuracy of the network on the 106 validation images: 0.8018867924528302
# Epoch [17/25], Step [11/11], Loss: 0.4417
# Accuracy of the network on the 106 validation images: 0.7830188679245284
# Epoch [18/25], Step [11/11], Loss: 0.3275
# Accuracy of the network on the 106 validation images: 0.839622641509434
# Epoch [19/25], Step [11/11], Loss: 0.1569
# Accuracy of the network on the 106 validation images: 0.6886792452830188
# Epoch [20/25], Step [11/11], Loss: 0.2393
# Accuracy of the network on the 106 validation images: 0.660377358490566
# Epoch [21/25], Step [11/11], Loss: 0.1007
# Accuracy of the network on the 106 validation images: 0.8773584905660378
# Epoch [22/25], Step [11/11], Loss: 0.4768
# Accuracy of the network on the 106 validation images: 0.7264150943396226
# Epoch [23/25], Step [11/11], Loss: 0.3219
# Accuracy of the network on the 106 validation images: 0.8018867924528302
# Epoch [24/25], Step [11/11], Loss: 0.2693
# Accuracy of the network on the 106 validation images: 0.839622641509434
# Epoch [25/25], Step [11/11], Loss: 0.2618
# Accuracy of the network on the 106 validation images: 0.7547169811320755
# Accuracy of the network on the 163 test images: 0.7791411042944786

# %%
num_classes = 10
num_epochs = 25
batch_size = 128
learning_rate = 0.0001

train_loader, valid_loader = get_train_valid_loader(train_dir, val_dir, batch_size, augment=True, random_seed=42)

model = AlexNet(num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

total_step = len(train_loader)


for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
          .format(epoch + 1, num_epochs, i + 1, total_step, loss.item()))
    
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in valid_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            del images, labels, outputs
    
        print('Accuracy of the network on the {} validation images: {} '.format(len(valid_loader.dataset), correct / total))

test_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs
        
    accuracy = correct/total
    accuracies = []
    accuracies.append(accuracy)
    print('Accuracy of the network on the {} test images: {} '.format(len(test_loader.dataset), accuracy))
# Out:
# Epoch [1/25], Step [6/6], Loss: 0.6507
# Accuracy of the network on the 106 validation images: 0.1792452830188679
# Epoch [2/25], Step [6/6], Loss: 0.8647
# Accuracy of the network on the 106 validation images: 0.8301886792452831
# Epoch [3/25], Step [6/6], Loss: 0.5807
# Accuracy of the network on the 106 validation images: 0.16981132075471697
# Epoch [4/25], Step [6/6], Loss: 0.7379
# Accuracy of the network on the 106 validation images: 0.16981132075471697
# Epoch [5/25], Step [6/6], Loss: 0.6711
# Accuracy of the network on the 106 validation images: 0.1792452830188679
# Epoch [6/25], Step [6/6], Loss: 0.5724
# Accuracy of the network on the 106 validation images: 0.42452830188679247
# Epoch [7/25], Step [6/6], Loss: 0.6764
# Accuracy of the network on the 106 validation images: 0.6415094339622641
# Epoch [8/25], Step [6/6], Loss: 0.4947
# Accuracy of the network on the 106 validation images: 0.8301886792452831
# Epoch [9/25], Step [6/6], Loss: 0.6264
# Accuracy of the network on the 106 validation images: 0.7264150943396226
# Epoch [10/25], Step [6/6], Loss: 0.2153
# Accuracy of the network on the 106 validation images: 0.7264150943396226
# Epoch [11/25], Step [6/6], Loss: 0.4077
# Accuracy of the network on the 106 validation images: 0.7735849056603774
# Epoch [12/25], Step [6/6], Loss: 0.4174
# Accuracy of the network on the 106 validation images: 0.7735849056603774
# Epoch [13/25], Step [6/6], Loss: 0.2504
# Accuracy of the network on the 106 validation images: 0.6698113207547169
# Epoch [14/25], Step [6/6], Loss: 0.2046
# Accuracy of the network on the 106 validation images: 0.5188679245283019
# Epoch [15/25], Step [6/6], Loss: 0.4347
# Accuracy of the network on the 106 validation images: 0.5188679245283019
# Epoch [16/25], Step [6/6], Loss: 0.4628
# Accuracy of the network on the 106 validation images: 0.8301886792452831
# Epoch [17/25], Step [6/6], Loss: 0.6791
# Accuracy of the network on the 106 validation images: 0.7735849056603774
# Epoch [18/25], Step [6/6], Loss: 0.3301
# Accuracy of the network on the 106 validation images: 0.6698113207547169
# Epoch [19/25], Step [6/6], Loss: 0.4278
# Accuracy of the network on the 106 validation images: 0.7452830188679245
# Epoch [20/25], Step [6/6], Loss: 0.3271
# Accuracy of the network on the 106 validation images: 0.8679245283018868
# Epoch [21/25], Step [6/6], Loss: 0.4258
# Accuracy of the network on the 106 validation images: 0.8301886792452831
# Epoch [22/25], Step [6/6], Loss: 0.3548
# Accuracy of the network on the 106 validation images: 0.6037735849056604
# Epoch [23/25], Step [6/6], Loss: 0.2634
# Accuracy of the network on the 106 validation images: 0.6320754716981132
# Epoch [24/25], Step [6/6], Loss: 0.5572
# Accuracy of the network on the 106 validation images: 0.8584905660377359
# Epoch [25/25], Step [6/6], Loss: 0.3679
# Accuracy of the network on the 106 validation images: 0.6792452830188679
# Accuracy of the network on the 163 test images: 0.7239263803680982

# %%
accuracies
# Out:
# [0.7239263803680982]

# %%
import matplotlib.pyplot as plt


# Plot the accuracies
plt.plot(range(1, num_epochs + 1), accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Test Accuracy over Epochs')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       1 import matplotlib.pyplot as plt
#       4 # Plot the accuracies
# ----> 5 plt.plot(range(1, num_epochs + 1), accuracies, label='Test Accuracy')
#       6 plt.xlabel('Epoch')
#       7 plt.ylabel('Accuracy')
#
# File ~/anaconda3/envs/research_project/lib/python3.10/site-packages/matplotlib/pyplot.py:3708, in plot(scalex, scaley, data, *args, **kwargs)
#    3700 @_copy_docstring_and_deprecators(Axes.plot)
#    3701 def plot(
#    3702     *args: float | ArrayLike | str,
#    (...)
#    3706     **kwargs,
#    3707 ) -> list[Line2D]:
# -> 3708     return gca().plot(
#    3709         *args,
#    3710         scalex=scalex,
#    3711         scaley=scaley,
#    3712         **({"data": data} if data is not None else {}),
#    3713         **kwargs,
#    3714     )
#
# File ~/anaconda3/envs/research_project/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~/anaconda3/envs/research_project/lib/python3.10/site-packages/matplotlib/axes/_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/research_project/lib/python3.10/site-packages/matplotlib/axes/_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (25,) and (1,)
